# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %%
df = pd.read_csv("raw_ksi_data.csv")

# %%
df['SEVERE_COLLISION'] = (
    (df['INJURY'].isin(['Major', 'Fatal']))
).astype(int)

# %%
df['SEVERE_COLLISION'].value_counts()
# Out:
# SEVERE_COLLISION
# 0    11536
# 1     7421
# Name: count, dtype: int64

# %%
speeding_df = df[df["SPEEDING"] == "Yes"]

# %%
df["SPEEDING"].value_counts()
# Out:
# SPEEDING
# Yes    2694
# Name: count, dtype: int64

# %%
speeding_df["SEVERE_COLLISION"].value_counts()
# Out:
# SEVERE_COLLISION
# 0    1674
# 1    1020
# Name: count, dtype: int64

# %%
df["ALCOHOL"].value_counts()
# Out:
# ALCOHOL
# Yes    808
# Name: count, dtype: int64

# %%
alcohol_df = df[df["ALCOHOL"] == "Yes"]

# %%
alcohol_df["SEVERE_COLLISION"].value_counts()
# Out:
# SEVERE_COLLISION
# 0    496
# 1    312
# Name: count, dtype: int64

# %%
df["DRIVCOND"].value_counts()
# Out:
# DRIVCOND
# Normal                                6158
# Inattentive                           1603
# Unknown                               1129
# Medical or Physical Disability         181
# Had Been Drinking                      166
# Ability Impaired, Alcohol Over .08     132
# Ability Impaired, Alcohol              122
# Other                                   97
# Fatigue                                 58
# Ability Impaired, Drugs                 20
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='DRIVCOND', hue='SEVERE_COLLISION', data=df, palette='coolwarm')
plt.title('Collision Severity by Driver Condition')
plt.xlabel('Light Condition')
plt.ylabel('Count')
plt.legend(title='Severe Collision', labels=['No (0)', 'Yes (1)'])
plt.xticks(rotation=45) 
plt.tight_layout()     
plt.show()

# %%
def simplify_driver_condition(cond):
    if cond == 'Normal':
        return 'Normal'
    elif cond == 'Inattentive':
        return 'Inattentive'
    elif cond == 'Fatigue':
        return 'Fatigue'
    elif cond in ['Had Been Drinking', 'Ability Impaired, Alcohol Over .08', 'Ability Impaired, Alcohol']:
        return 'Alcohol Impaired'
    elif cond == 'Ability Impaired, Drugs':
        return 'Drug Impaired'
    elif cond == 'Medical or Physical Disability':
        return 'Medical Condition'
    elif cond == 'Other':
        return 'Other'
    else:
        return 'Unknown'
df['DRIVCOND'] = df['DRIVCOND'].fillna('Normal')
df['DRIVCOND_GROUPED'] = df['DRIVCOND'].apply(simplify_driver_condition)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='DRIVCOND_GROUPED', hue='SEVERE_COLLISION', data=df, palette='coolwarm')
plt.title('Collision Severity by Driver Condition')
plt.xlabel('Driver Condition')
plt.ylabel('Count')
plt.legend(title='Severe Collision', labels=['No (0)', 'Yes (1)'])
plt.xticks(rotation=45) 
plt.tight_layout()     
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='AG_DRIV', hue='SEVERE_COLLISION', data=df, palette='coolwarm')
plt.title('Collision Severity by Aggrevated Driving')
plt.xlabel('Aggrevated')
plt.ylabel('Count')
plt.legend(title='Severe Collision', labels=['No (0)', 'Yes (1)'])
plt.xticks(rotation=45) 
plt.tight_layout()     
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='SPEEDING', hue='SEVERE_COLLISION', data=df, palette='coolwarm')
plt.title('Collision Severity by SPEEDING')
plt.xlabel('SPEEDING')
plt.ylabel('Count')
plt.legend(title='Severe Collision', labels=['No (0)', 'Yes (1)'])
plt.xticks(rotation=45) 
plt.tight_layout()     
plt.show()

# %%
df["VEHTYPE"].value_counts()
# Out:
# VEHTYPE
# Automobile, Station Wagon        7805
# Other                            4753
# Bicycle                           819
# Motorcycle                        747
# Municipal Transit Bus (TTC)       284
# Pick Up Truck                     270
# Truck - Open                      182
# Passenger Van                     143
# Delivery Van                       87
# Truck - Closed (Blazer, etc)       71
# Street Car                         52
# Truck - Dump                       52
# Truck-Tractor                      42
# Taxi                               28
# Moped                              24
# Bus (Other) (Go Bus, Gray Coa      20
# Truck (other)                      20
# Intercity Bus                      14
# Truck - Tank                       11
# Tow Truck                           9
# Police Vehicle                      7
# School Bus                          6
# Unknown                             6
# Construction Equipment              4
# Rickshaw                            4
# Fire Vehicle                        3
# Truck - Car Carrier                 2
# Other Emergency Vehicle             1
# Off Road - 2 Wheels                 1
# Ambulance                           1
# Off Road - 4 Wheels                 1
# Off Road - Other                    1
# Name: count, dtype: int64

# %%
def categorize_vehicle(v):
    if v in ["Automobile, Station Wagon", "Passenger Van", "Taxi", "Other"]:
        return "Car"
    elif v in [
        "Pick Up Truck", "Truck – Open", "Truck – Closed (Blazer, etc)",
        "Truck – Dump", "Truck–Tractor", "Delivery Van",
        "Tow Truck", "Truck (other)", "Truck – Car Carrier",
        "Construction Equipment"
    ]:
        return "Truck"
    elif v in [
        "Municipal Transit Bus (TTC)", "Bus (Other) (Go Bus, Gray Coa)",
        "Intercity Bus", "School Bus"
    ]:
        return "Bus"
    elif v in ["Motorcycle", "Bicycle", "Moped", "Rickshaw"]:
        return "Two Wheeler"
    elif v in ["Police Vehicle", "Fire Vehicle", "Ambulance", "Other Emergency Vehicle"]:
        return "Emergency"
    else:
        return "Car"

# %%
df["VEHTYPE_GROUPED"] = df["VEHTYPE"].apply(categorize_vehicle)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='VEHTYPE_GROUPED', hue='SEVERE_COLLISION', data=df, palette='coolwarm')
plt.title('Collision Severity by Vehicle Type')
plt.xlabel('Vehicle Type')
plt.ylabel('Count')
plt.legend(title='Severe Collision', labels=['No (0)', 'Yes (1)'])
plt.xticks(rotation=45) 
plt.tight_layout()     
plt.show()

# %%
df["DRIVACT"].value_counts()
# Out:
# DRIVACT
# Driving Properly                4425
# Failed to Yield Right of Way    1603
# Lost control                    1007
# Improper Turn                    614
# Other                            529
# Disobeyed Traffic Control        497
# Exceeding Speed Limit            264
# Following too Close              254
# Speed too Fast For Condition     216
# Improper Lane Change             125
# Improper Passing                 121
# Wrong Way on One Way Road          9
# Speed too Slow                     4
# Name: count, dtype: int64

# %%
def categorize_drivact(a):
    if a == "Driving Properly":
        return "No Apparent Error"
    elif a in ["Failed to Yield Right of Way", "Disobeyed Traffic Control", "Wrong Way on One Way Road"]:
        return "Right-of-Way / Traffic Violation"
    elif a in ["Exceeding Speed Limit", "Speed too Fast For Condition", "Speed too Slow"]:
        return "Speed-Related"
    elif a in ["Lost control", "Improper Turn", "Following too Close", "Improper Lane Change", "Improper Passing"]:
        return "Control / Maneuver Error"
    else:
        return "Other / Unknown"

# %%
df["DRIVACT_GROUPED"] = df["DRIVACT"].apply(categorize_drivact)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='DRIVACT_GROUPED', hue='SEVERE_COLLISION', data=df, palette='coolwarm')
plt.title('Collision Severity by Driver Action')
plt.xlabel(' Driver Action')
plt.ylabel('Count')
plt.legend(title='Severe Collision', labels=['No (0)', 'Yes (1)'])
plt.xticks(rotation=45) 
plt.tight_layout()     
plt.show()

# %%
df["IMPACTYPE"].isna().sum()
# Out:
# np.int64(27)

# %%
df["IMPACTYPE"].value_counts()
# Out:
# IMPACTYPE
# Pedestrian Collisions     7684
# Turning Movement          2934
# Cyclist Collisions        1861
# Rear End                  1804
# SMV Other                 1465
# Angle                     1304
# Approaching                959
# Sideswipe                  522
# Other                      204
# SMV Unattended Vehicle     193
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='IMPACTYPE', hue='SEVERE_COLLISION', data=df, palette='coolwarm')
plt.title('Collision Severity by Impact Type')
plt.xlabel('Impact Type')
plt.ylabel('Count')
plt.legend(title='Severe Collision', labels=['No (0)', 'Yes (1)'])
plt.xticks(rotation=45) 
plt.tight_layout()     
plt.show()

# %%
def categorize_impact(impact):
    if impact in ["Pedestrian Collisions", "Cyclist Collisions"]:
        return "Pedestrian/Cyclist"
    elif impact == "Rear End":
        return "Rear End"
    elif impact in ["Sideswipe", "Approaching"]:
        return "Sideswipe/Approaching"
    elif impact in ["Angle", "Turning Movement"]:
        return "T-Bone"
    elif impact in ["SMV Other", "SMV Unattended Vehicle"]:
        return "SlowMoving/Parked"
    else:
        return "Other/Unknown"

# %%
df["IMPACT_TYPE"] = df["IMPACTYPE"].apply(categorize_impact)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='IMPACT_TYPE', hue='SEVERE_COLLISION', data=df, palette='coolwarm')
plt.title('Collision Severity by Impact Type')
plt.xlabel('Impact Type')
plt.ylabel('Count')
plt.legend(title='Severe Collision', labels=['No (0)', 'Yes (1)'])
plt.xticks(rotation=45) 
plt.tight_layout()     
plt.show()

# %%
df["INVAGE"].value_counts()
# Out:
# INVAGE
# unknown     2625
# 20 to 24    1800
# 25 to 29    1723
# 30 to 34    1450
# 35 to 39    1382
# 50 to 54    1353
# 40 to 44    1314
# 45 to 49    1293
# 55 to 59    1156
# 60 to 64     925
# 15 to 19     883
# 65 to 69     723
# 70 to 74     560
# 75 to 79     456
# 80 to 84     351
# 10 to 14     260
# 85 to 89     224
# 5 to 9       206
# 0 to 4       190
# 90 to 94      68
# Over 95       15
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='INVAGE', hue='SEVERE_COLLISION', data=df, palette='coolwarm')
plt.title('Collision Severity by Driver Age')
plt.xlabel('Age Condition')
plt.ylabel('Count')
plt.legend(title='Severe Collision', labels=['No (0)', 'Yes (1)'])
plt.xticks(rotation=45) 
plt.tight_layout()     
plt.show()

# %%
df[df["NEIGHBOURHOOD_140"] == "NSA"].shape
# Out:
# (154, 59)

# %%
misMatch = df[df["HOOD_140"] != df["HOOD_158"]]

# %%
misMatch.columns[-10:]
# Out:
# Index(['HOOD_140', 'NEIGHBOURHOOD_140', 'DIVISION', 'x', 'y',
#        'SEVERE_COLLISION', 'DRIVCOND_GROUPED', 'VEHTYPE_GROUPED',
#        'DRIVACT_GROUPED', 'IMPACT_TYPE'],
#       dtype='object')

# %%
misMatch.iloc[:, -12:]
# Out:
#       HOOD_158                      NEIGHBOURHOOD_158 HOOD_140  \
# 19         144                    Morningside Heights      131
# 20         144                    Morningside Heights      131
# 21         144                    Morningside Heights      131
# 22         166  St Lawrence-East Bayfront-The Islands       77
# 23         166  St Lawrence-East Bayfront-The Islands       77
# ...        ...                                    ...      ...
# 18922      153                               Avondale       51
# 18934      166  St Lawrence-East Bayfront-The Islands       73
# 18935      166  St Lawrence-East Bayfront-The Islands       73
# 18951      142                           Woburn North      137
# 18952      142                           Woburn North      137
#
#                             NEIGHBOURHOOD_140 DIVISION            x  \
# 19                                Rouge (131)      D42  642702.4974
# 20                                Rouge (131)      D42  642702.4974
# 21                                Rouge (131)      D42  642702.4974
# 22     Waterfront Communities-The Island (77)      D51  632036.3952
# 23     Waterfront Communities-The Island (77)      D51  632036.3952
# ...                                       ...      ...          ...
# 18922                    Willowdale East (51)      D32  628042.1066
# 18934                          Moss Park (73)      D51  631336.3423
# 18935                          Moss Park (73)      D51  631336.3423
# 18951                            Woburn (137)      D43  640724.2608
# 18952                            Woburn (137)      D43  640724.2608
#
#                   y  SEVERE_COLLISION DRIVCOND_GROUPED VEHTYPE_GROUPED  \
# 19     4.855938e+06                 1          Unknown             Car
# 20     4.855938e+06                 0           Normal             Car
# 21     4.855938e+06                 1           Normal             Car
# 22     4.834468e+06                 0           Normal             Car
# 23     4.834468e+06                 1           Normal             Car
# ...             ...               ...              ...             ...
# 18922  4.846483e+06                 1           Normal             Car
# 18934  4.834227e+06                 0           Normal           Truck
# 18935  4.834227e+06                 1           Normal     Two Wheeler
# 18951  4.848051e+06                 0           Normal             Car
# 18952  4.848051e+06                 1           Normal             Car
#
#                         DRIVACT_GROUPED            IMPACT_TYPE
# 19             Control / Maneuver Error  Sideswipe/Approaching
# 20                      Other / Unknown  Sideswipe/Approaching
# 21                    No Apparent Error  Sideswipe/Approaching
# 22     Right-of-Way / Traffic Violation                 T-Bone
# 23                    No Apparent Error                 T-Bone
# ...                                 ...                    ...
# 18922                   Other / Unknown     Pedestrian/Cyclist
# 18934                 No Apparent Error     Pedestrian/Cyclist
# 18935                   Other / Unknown     Pedestrian/Cyclist
# 18951  Right-of-Way / Traffic Violation     Pedestrian/Cyclist
# 18952                   Other / Unknown     Pedestrian/Cyclist
#
# [4843 rows x 12 columns]

# %%
misMatch.shape
# Out:
# (4843, 59)

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='NEIGHBOURHOOD_158', hue='SEVERE_COLLISION', data=df, palette='coolwarm')
plt.title('Collision Severity by Driver Condition')
plt.xlabel('Light Condition')
plt.ylabel('Count')
plt.legend(title='Severe Collision', labels=['No (0)', 'Yes (1)'])
plt.xticks(rotation=45) 
plt.tight_layout()     
plt.show()

# %%
pd.set_option('display.max_rows', None)
print(df["NEIGHBOURHOOD_140"].value_counts())
pd.reset_option('display.max_rows')
# Out:
# NEIGHBOURHOOD_140
# Waterfront Communities-The Island (77)      740
# West Humber-Clairville (1)                  592
# Bay Street Corridor (76)                    445
# Woburn (137)                                409
# Wexford/Maryvale (119)                      361
# South Riverdale (70)                        355
# Islington-City Centre West (14)             326
# Downsview-Roding-CFB (26)                   314
# Rouge (131)                                 295
# South Parkdale (85)                         295
# Church-Yonge Corridor (75)                  293
# Clairlea-Birchmount (120)                   287
# Mimico (includes Humber Bay Shores) (17)    280
# York University Heights (27)                271
# Kensington-Chinatown (78)                   268
# Moss Park (73)                              268
# Milliken (130)                              256
# Malvern (132)                               250
# Dovercourt-Wallace Emerson-Junction (93)    238
# Annex (95)                                  236
# Bendale (127)                               233
# Niagara (82)                                226
# Tam O'Shanter-Sullivan (118)                218
# L'Amoreaux (117)                            205
# Banbury-Don Mills (42)                      198
# Agincourt North (129)                       194
# Willowdale East (51)                        189
# Agincourt South-Malvern West (128)          181
# Kennedy Park (124)                          180
# High Park-Swansea (87)                      179
# Rockcliffe-Smythe (111)                     177
# Dorset Park (126)                           174
# Steeles (116)                               169
# West Hill (136)                             169
# Glenfield-Jane Heights (25)                 168
# Keelesdale-Eglinton West (110)              162
# Stonegate-Queensway (16)                    161
# Mount Olive-Silverstone-Jamestown (2)       154
# NSA                                         154
# Old East York (58)                          150
# Junction Area (90)                          148
# Eglinton East (138)                         145
# Clanton Park (33)                           141
# Victoria Village (43)                       141
# Bedford Park-Nortown (39)                   137
# Yorkdale-Glen Park (31)                     136
# Don Valley Village (47)                     136
# East End-Danforth (62)                      135
# Newtonbrook West (36)                       135
# Birchcliffe-Cliffside (122)                 135
# Trinity-Bellwoods (81)                      135
# Newtonbrook East (50)                       133
# Humber Summit (21)                          132
# Rosedale-Moore Park (98)                    129
# Dufferin Grove (83)                         127
# Bayview Village (52)                        125
# Corso Italia-Davenport (92)                 123
# Oakwood Village (107)                       122
# Bathurst Manor (34)                         119
# Little Portugal (84)                        119
# Humbermede (22)                             116
# Brookhaven-Amesbury (30)                    116
# Cabbagetown-South St.James Town (71)        113
# Mount Pleasant West (104)                   113
# University (79)                             112
# North Riverdale (68)                        112
# Wychwood (94)                               110
# Flemingdon Park (44)                        110
# St.Andrew-Windfields (40)                   108
# Alderwood (20)                              107
# Willowridge-Martingrove-Richview (7)        107
# Weston (113)                                104
# Kingsview Village-The Westway (6)           103
# Thistletown-Beaumond Heights (3)            100
# Woodbine Corridor (64)                       98
# Pelmo Park-Humberlea (23)                    97
# Edenbridge-Humber Valley (9)                 97
# Eringate-Centennial-West Deane (11)          97
# Cliffcrest (123)                             96
# Roncesvalles (86)                            95
# Rexdale-Kipling (4)                          94
# Scarborough Village (139)                    94
# The Beaches (63)                             93
# Lansing-Westgate (38)                        93
# Weston-Pellam Park (91)                      93
# Palmerston-Little Italy (80)                 91
# Casa Loma (96)                               91
# Leaside-Bennington (56)                      90
# Mount Pleasant East (99)                     90
# New Toronto (18)                             88
# Centennial Scarborough (133)                 88
# Greenwood-Coxwell (65)                       87
# Caledonia-Fairbank (109)                     86
# Hillcrest Village (48)                       81
# Broadview North (57)                         78
# Briar Hill-Belgravia (108)                   77
# Mount Dennis (115)                           76
# Lawrence Park South (103)                    76
# Oakridge (121)                               76
# Black Creek (24)                             75
# Humber Heights-Westmount (8)                 73
# Beechborough-Greenbrook (112)                71
# Regent Park (72)                             70
# Parkwoods-Donalda (45)                       68
# Yonge-Eglinton (100)                         67
# Willowdale West (37)                         66
# Morningside (135)                            66
# Thorncliffe Park (55)                        62
# Englemount-Lawrence (32)                     62
# Yonge-St.Clair (97)                          60
# Forest Hill South (101)                      60
# Danforth East York (59)                      59
# Etobicoke West Mall (13)                     58
# Westminster-Branson (35)                     58
# Henry Farm (53)                              58
# Bayview Woods-Steeles (49)                   57
# Humewood-Cedarvale (106)                     57
# Princess-Rosethorn (10)                      57
# Forest Hill North (102)                      57
# O'Connor-Parkview (54)                       55
# High Park North (88)                         54
# Runnymede-Bloor West Village (89)            50
# Long Branch (19)                             49
# Blake-Jones (69)                             49
# Bridle Path-Sunnybrook-York Mills (41)       48
# Markland Wood (12)                           47
# Ionview (125)                                44
# Pleasant View (46)                           44
# Woodbine-Lumsden (60)                        43
# Taylor-Massey (61)                           42
# Kingsway South (15)                          41
# North St.James Town (74)                     40
# Elms-Old Rexdale (5)                         37
# Highland Creek (134)                         35
# Lawrence Park North (105)                    34
# Rustic (28)                                  34
# Maple Leaf (29)                              33
# Danforth (66)                                28
# Guildwood (140)                              25
# Playter Estates-Danforth (67)                20
# Lambton Baby Point (114)                     18
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14, 12))
sns.scatterplot(
    data=df,
    x='LONGITUDE', y='LATITUDE',
    hue='NEIGHBOURHOOD_158',   # or 'NEIGHBOURHOOD'
    palette='tab20', # or 'Set1', 'viridis', 'Spectral'
    s=5,
    alpha=0.5,
    linewidth=0
)
# Out:
# <Axes: xlabel='LONGITUDE', ylabel='LATITUDE'>
