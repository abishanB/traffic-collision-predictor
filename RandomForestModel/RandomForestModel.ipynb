# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import joblib
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.tree import export_text
from sklearn.tree import plot_tree

# %%
df = pd.read_csv("ksi_collisions.csv")

# %%
df.sample(2)
# Out:
#             DATE        STREET1           STREET2        DISTRICT   LATITUDE  \
# 7021  2011-07-15   DON MILLS RD        WYNFORD DR      North York  43.723445
# 2369  2007-08-19  ISLINGTON AVE  ROWNTREE MILL RD  Etobicoke York  43.753345
#
#       LONGITUDE VISIBILITY     LIGHT ROAD_CONDITION           ACCLASS  ...  \
# 7021  -79.33969      Clear  Daylight            Dry  Non-Fatal Injury  ...
# 2369  -79.56859      Clear  Daylight            Dry  Non-Fatal Injury  ...
#
#      HOUR  YEAR MONTH  SEVERE_COLLISION       TIME_OF_DAY  SEASON  \
# 7021   16  2011     7                 0           Evening  Summer
# 2369   11  2007     8                 1  MorningAfternoon  Summer
#
#       VEHICLE_TYPE           DRIVER_ACTION         IMPACT_TYPE  AGE_RANGE
# 7021           Car  Control/Maneuver Error  Pedestrian/Cyclist      50–59
# 2369           Car           Other/Unknown  Pedestrian/Cyclist      70–79
#
# [2 rows x 29 columns]

# %%
categorical_features = ['LIGHT', 'VISIBILITY', 'ROAD_CONDITION', 'DOW', 'TIME_OF_DAY',
                        'SEASON', 'VEHICLE_TYPE', 'DRIVER_ACTION', 'IMPACT_TYPE', 'NEIGHBOURHOOD', 'AGE_RANGE']

# %%
target = 'SEVERE_COLLISION'

# %%
X = df[categorical_features]
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ]
)

model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(
        n_estimators=85,
        max_depth=24,
        max_features = 'sqrt',
        random_state=42,
        n_jobs=-1
    ))
])

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['LIGHT', 'VISIBILITY',
#                                                    'ROAD_CONDITION', 'DOW',
#                                                    'TIME_OF_DAY', 'SEASON',
#                                                    'VEHICLE_TYPE',
#                                                    'DRIVER_ACTION',
#                                                    'IMPACT_TYPE',
#                                                    'NEIGHBOURHOOD',
#                                                    'AGE_RANGE'])])),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=24, n_estimators=85,
#                                         n_jobs=-1, random_state=42))])

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.75      0.73      2900
#            1       0.72      0.69      0.70      2680
#
#     accuracy                           0.72      5580
#    macro avg       0.72      0.72      0.72      5580
# weighted avg       0.72      0.72      0.72      5580

# %%
train_score = model.score(X_train, y_train)
test_score = model.score(X_test, y_test)

print(f"Train accuracy: {train_score:.3f}")
print(f"Test accuracy: {test_score:.3f}")
# Out:
# Train accuracy: 0.837
# Test accuracy: 0.720

# %%
valid_categories = {
    col: set(X_train[col].dropna().unique())
    for col in categorical_features
}

print(valid_categories)
# Out:
# {'LIGHT': {'Twilight', 'Daylight', 'Dark'}, 'VISIBILITY': {'Rain', 'Clear', 'Snow'}, 'ROAD_CONDITION': {'SnowIce', 'Wet', 'Dry'}, 'DOW': {'Tuesday', 'Sunday', 'Monday', 'Friday', 'Saturday', 'Wednesday', 'Thursday'}, 'TIME_OF_DAY': {'LateNight', 'Night', 'Evening', 'MorningAfternoon'}, 'SEASON': {'Summer', 'Fall', 'Spring', 'Winter'}, 'VEHICLE_TYPE': {'Car', 'Bus', 'Two Wheeler', 'Emergency', 'Truck'}, 'DRIVER_ACTION': {'Right-of-Way/Traffic Violation', 'Speed-Related', 'Control/Maneuver Error', 'Other/Unknown'}, 'IMPACT_TYPE': {'Rear End', 'Pedestrian/Cyclist', 'Slow/Parked', 'Sideswipe/Approaching', 'T-Bone'}, 'NEIGHBOURHOOD': {'Birchcliffe-Cliffside', 'Blake-Jones', 'Willowridge-Martingrove-Richview', 'Woodbine-Lumsden', 'Wellington Place', 'Rexdale-Kipling', 'Humber Summit', 'Woburn North', 'Bayview Village', 'Cliffcrest', 'Bendale South', 'Milliken', 'Banbury-Don Mills', 'Centennial Scarborough', 'Forest Hill North', 'Taylor-Massey', 'Thistletown-Beaumond Heights', 'Kingsway South', 'Yonge-Eglinton', 'Kingsview Village-The Westway', 'Thorncliffe Park', 'Regent Park', 'Danforth East York', 'South Riverdale', 'Leaside-Bennington', 'High Park-Swansea', 'St.Andrew-Windfields', 'Downtown Yonge East', 'Humber Bay Shores', 'Elms-Old Rexdale', 'Willowdale West', 'Islington', 'Caledonia-Fairbank', 'Dovercourt Village', 'Junction-Wallace Emerson', 'Highland Creek', 'Avondale', 'Morningside', 'Little Portugal', 'Glenfield-Jane Heights', 'Yonge-Bay Corridor', 'Brookhaven-Amesbury', 'Rosedale-Moore Park', 'East End-Danforth', 'Weston', 'Maple Leaf', 'Englemount-Lawrence', 'Wexford/Maryvale', 'West Queen West', 'North Riverdale', 'Morningside Heights', 'Lambton Baby Point', 'Danforth', 'Bathurst Manor', 'West Rouge', 'Corso Italia-Davenport', 'Runnymede-Bloor West Village', 'Forest Hill South', 'East Willowdale', 'Bridle Path-Sunnybrook-York Mills', 'Agincourt North', 'Scarborough Village', 'High Park North', 'Kensington-Chinatown', 'West Humber-Clairville', 'The Beaches', 'Etobicoke West Mall', 'Long Branch', 'Bayview Woods-Steeles', 'North St.James Town', 'Eringate-Centennial-West Deane', 'Dorset Park', "Parkwoods-O'Connor Hills", 'Roncesvalles', 'Rustic', 'Cabbagetown-South St.James Town', 'Playter Estates-Danforth', 'Yonge-St.Clair', 'Woodbine Corridor', 'Oakridge', 'Moss Park', 'Broadview North', 'Steeles', 'Oakwood Village', 'Princess-Rosethorn', 'Pleasant View', 'Bendale-Glen Andrew', 'Newtonbrook West', 'Malvern East', 'Pelmo Park-Humberlea', 'Humewood-Cedarvale', "L'Amoreaux West", 'Humber Heights-Westmount', 'Mimico-Queensway', "O'Connor-Parkview", 'Yorkdale-Glen Park', 'Rockcliffe-Smythe', 'North Toronto', 'St Lawrence-East Bayfront-The Islands', 'Beechborough-Greenbrook', 'Malvern West', 'Newtonbrook East', 'Greenwood-Coxwell', 'Henry Farm', 'Lansing-Westgate', 'Old East York', 'Wychwood', 'Agincourt South-Malvern West', 'Palmerston-Little Italy', 'Clairlea-Birchmount', 'Briar Hill-Belgravia', 'South Eglinton-Davisville', 'Casa Loma', 'Bay-Cloverhill', 'Trinity-Bellwoods', 'Harbourfront-CityPlace', 'Westminster-Branson', 'Mount Pleasant East', "Tam O'Shanter-Sullivan", 'Mount Dennis', 'Ionview', 'Victoria Village', 'Kennedy Park', 'Fenside-Parkwoods', 'Fort York-Liberty Village', 'Church-Wellesley', 'Weston-Pelham Park', 'Yonge-Doris', 'Eglinton East', "East L'Amoreaux", 'South Parkdale', 'Hillcrest Village', 'Edenbridge-Humber Valley', 'Keelesdale-Eglinton West', 'West Hill', 'Markland Wood', 'Flemingdon Park', 'Golfdale-Cedarbrae-Woburn', 'Don Valley Village', 'Downsview', 'Humbermede', 'Black Creek', 'York University Heights', 'Bedford Park-Nortown', 'Mount Olive-Silverstone-Jamestown', 'Etobicoke City Centre', 'Lawrence Park South', 'Alderwood', 'Stonegate-Queensway', 'Annex', 'New Toronto', 'University', 'Junction Area', 'Oakdale-Beverley Heights', 'Lawrence Park North', 'Dufferin Grove', 'Clanton Park', 'Guildwood'}, 'AGE_RANGE': {'50–59', '90+', '20–29', '30–39', '10–19', 'Unknown', '40–49', '60–69', '80–89', '0–9',  ...

# %%
#save model
joblib.dump({
    "model": model,
    "valid_categories": valid_categories
}, "model.joblib")
# Out:
# ['model.joblib']

# %%
y_proba = model.predict_proba(df)[:, 1]

# %%
plt.figure(figsize=(10,5))
plt.hist(y_proba, bins=30, color='skyblue', edgecolor='black')
plt.title("Distribution of Predicted Probabilities (Severe Collision)")
plt.xlabel("Predicted Probability")
plt.ylabel("Frequency")
plt.show()

# %%
bins = np.arange(0.5, 0.61, 0.01)

plt.figure(figsize=(8,5))
counts, bins, patches = plt.hist(
    y_proba, bins=bins, color='skyblue', edgecolor='black', alpha=0.8
)

plt.title("Predicted Probability Distribution (0.5–0.6 Range)", fontsize=14)
plt.xlabel("Predicted Probability (Severe Collision)", fontsize=12)
plt.ylabel("Frequency", fontsize=12)

for i, count in enumerate(counts):
    plt.text(bins[i] + 0.005, count + 0.5, str(int(count)), ha='center', fontsize=9)

plt.axvline(0.5, color='orange', linestyle='--', linewidth=2, label='Threshold = 0.5')

plt.xlim(0.5, 0.6)
plt.xticks(np.arange(0.5, 0.61, 0.01))
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.show()
